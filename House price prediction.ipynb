# %%
import numpy as np
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("train.csv")
df_test=pd.read_csv("test.csv")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df['Alley'].isna().sum()
# Out:
# 1369

# %%
df['PoolQC'].isna().sum()
# Out:
# 1453

# %%
df['Fence'].isna().sum()
# Out:
# 1179

# %%
df['MiscFeature'].isna().sum()
# Out:
# 1406

# %%
df.drop(['MiscFeature','Alley','Fence','PoolQC'],axis=1, inplace=True)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
df.drop(['OverallQual','GrLivArea','TotalBsmtSF','1stFlrSF','GrLivArea','GarageCars','GarageArea'],axis=1,inplace=True)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %%
le=LabelEncoder()
columns_cat = df.select_dtypes(include=['object']).columns.tolist()
df[columns_cat]= df[columns_cat].fillna(df[columns_cat].mode().iloc[0])
df[columns_cat] = df[columns_cat].apply(lambda col: le.fit_transform(col.astype(str)))

# %%
df.dropna(inplace=True)

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.2,random_state=1)

# %%
mr=LinearRegression()
mr.fit(X_train,y_train)
y_pred=mr.predict(X_test)
print("mean absolute error:",mean_absolute_error(y_test,y_pred))
print("mean squared error:",mean_squared_error(y_test,y_pred))
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,y_pred)))
print("r2-score:",r2_score(y_test,y_pred))
# Out:
# mean absolute error: 21974.679458856823
# mean squared error: 984421257.8265804
# root mean squared error: 31375.488168737396
# r2-score: 0.844531501708797

# %%
rs=RandomForestRegressor()
rs.fit(X_train,y_train)
y_pred1=rs.predict(X_test)
y_pred1
print("mean absolute error:",mean_absolute_error(y_test,y_pred1))
print("mean squared error:",mean_squared_error(y_test,y_pred1))
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,y_pred1)))
print("R2 score:",r2_score(y_test,y_pred1))
# Out:
# mean absolute error: 19833.947733333334
# mean squared error: 869239610.4982978
# root mean squared error: 29482.86978057424
# R2 score: 0.8627220046042451

# %%
gb=GradientBoostingRegressor()
gb.fit(X_train,y_train)
y_pred3=gb.predict(X_test)
y_pred3
print("mean absolute error:",mean_absolute_error(y_test,y_pred3))
print("mean squared error:",mean_squared_error(y_test,y_pred3))
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,y_pred3)))
print("R2 score:",r2_score(y_test,y_pred3))
# Out:
# mean absolute error: 20379.36877863176
# mean squared error: 962992857.6092887
# root mean squared error: 31032.126217990426
# R2 score: 0.8479156639016375

# %%
ad=AdaBoostRegressor()
ad.fit(X_train,y_train)
y_pred4=gb.predict(X_test)
y_pred4
print("mean absolute error:",mean_absolute_error(y_test,y_pred4))
print("mean squared error:",mean_squared_error(y_test,y_pred4))
print("root mean squared error:",np.sqrt(mean_squared_error(y_test,y_pred4)))
print("R2 score:",r2_score(y_test,y_pred4))
# Out:
# mean absolute error: 20379.36877863176
# mean squared error: 962992857.6092887
# root mean squared error: 31032.126217990426
# R2 score: 0.8479156639016375

# %%
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df_test.drop(['MiscFeature','Alley','Fence','PoolQC'],axis=1, inplace=True)

# %%
df_test.drop(['OverallQual','GrLivArea','TotalBsmtSF','1stFlrSF','GrLivArea','GarageCars','GarageArea'],axis=1,inplace=True)

# %%
df_test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0     1461          20       RH         80.0    11622   Pave      Reg
# 1     1462          20       RL         81.0    14267   Pave      IR1
# 2     1463          60       RL         74.0    13830   Pave      IR1
# 3     1464          60       RL         78.0     9978   Pave      IR1
# 4     1465         120       RL         43.0     5005   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1454  2915         160       RM         21.0     1936   Pave      Reg
# 1455  2916         160       RM         21.0     1894   Pave      Reg
# 1456  2917          20       RL        160.0    20000   Pave      Reg
# 1457  2918          85       RL         62.0    10441   Pave      Reg
# 1458  2919          60       RL         74.0     9627   Pave      Reg
#
#      LandContour Utilities LotConfig  ... OpenPorchSF EnclosedPorch 3SsnPorch  \
# ...

# %%
df_test.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 70, dtype: int64

# %%
columns_cat = df_test.select_dtypes(include=['object']).columns.tolist()
df_test[columns_cat]= df_test[columns_cat].fillna(df_test[columns_cat].mode().iloc[0])
df_test[columns_cat] = df_test[columns_cat].apply(lambda col: le.fit_transform(col.astype(str)))

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')  
df_test_imputed = imputer.fit_transform(df_test)

# %%
test_preds = mr.predict(df_test_imputed)
test_preds
# Out:
# array([ 89833.3599961 ,  24926.2614121 , 159386.63924127, ...,
#        118460.05591691,  93260.83669035, 213144.59553968])

# %%
mr_pred=pd.DataFrame({'id': df_test['Id'], 'SalePrice':test_preds })
mr_pred.to_csv('submission.csv', index=False)
mr_pred
# Out:
#         id      SalePrice
# 0     1461   89833.359996
# 1     1462   24926.261412
# 2     1463  159386.639241
# 3     1464  179928.471556
# 4     1465  148520.513929
# ...    ...            ...
# 1454  2915   54776.628957
# 1455  2916   47153.323337
# 1456  2917  118460.055917
# 1457  2918   93260.836690
# 1458  2919  213144.595540
#
# [1459 rows x 2 columns]
